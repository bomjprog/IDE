# %%
import requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js' 
response = requests.get(url)
response
# Out:
# c:\Users\evgus\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# <Response [200]>

# %%
from pprint import pprint 
currencies = response.json() 
pprint(currencies)
# Out:
# {'Date': '2023-08-16T11:30:00+03:00',
#  'PreviousDate': '2023-08-15T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2023/08/15/daily_json.js',
#  'Timestamp': '2023-08-15T17:00:00+03:00',
#  'Valute': {'AED': {'CharCode': 'AED',
#                     'ID': 'R01230',
#                     'Name': 'Дирхам ОАЭ',
#                     'Nominal': 1,
#                     'NumCode': '784',
#                     'Previous': 27.5088,
#                     'Value': 26.5237},
#             'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 26.1348,
#                     'Value': 25.1957},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
# ...

# %%
response = requests.get('https://www.youtube.com/')
pprint(response.text)
# Out:
# ('<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, '
#  'sans-serif;" lang="ru-RU" system-icons typography typography-spacing '
#  'darker-dark-theme darker-dark-theme-deprecate><head><script data-id="_gd" '
#  'nonce="Xv8V5gChz7x5V-u_sduUVg">window.WIZ_global_data = '
#  '{"MuJWjd":false,"nQyAE":{},"oxN3nb":{"1":false}};</script><meta '
#  'http-equiv="X-UA-Compatible" content="IE=edge"/><meta '
#  'http-equiv="origin-trial" '
#  'content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ=="/><script '
#  'nonce="Xv8V5gChz7x5V-u_sduUVg">var ytcfg={d:function(){return '
#  'window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return '
#  'k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var '
# ...

# %%
from bs4 import BeautifulSoup

# %%
token = '36a16e2f36a16e2f36a16e2f5a35b43a6f336a136a16e2f527ae82e81e043bfefb2763c' 
url = 'https://api.vk.com/method/users.get' 
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex', 'access_token': token, 'lang': 'ru'}
response = requests.get(url, params=params)

# %%
f = 0
d = 0
response = requests.get(url, params={'user_id': ",".join(map(str, range(1, 501))), 'v': 5.95, 'fields': 'sex', 'access_token': token, 'lang': 'ru'})
for i in range(500):
    sex = response.json()['response'][i]['sex']
    if sex == 1:
        f += 1
        d+=1
    elif sex == 2:
        d += 1
f/d
# Out:
# 0.48699763593380613

# %%
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data)
# Out:
# {'response': {'count': 13325489, 'items': [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 421, 450, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 831, 832, 834, 847, 900, 905, 907, 914, 930, 943, 952, 958, 966, 976, 979, 997, 1000, 1018, 1023, 1032, 1033, 1038, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1301, 1333, 1334, 1336, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1503, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2136, 2150, 2195, 2201, 2230, 2236, 2273, 2281, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2512, 2513, 2515, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2909, 2919, 2922, 2953, 2962, 2982, 3001, 3006, 3
# ...

# %%
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'В VK Звонках появились новые ф': [306, 555, 176, 1691589248],
#  'ВКонтакте впервые проведёт трё': [159, 804, 319, 1688034811],
#  'Встречайте бета-версию мобильн': [680, 737, 231, 1688055462],
#  'Загружайте свои красочные сним': [282, 921, 357, 1691058137],
#  'Лето, солнце, новинки ВКонтакт': [190, 398, 41, 1691511278],
#  'Погрузитесь в прошлогоднее лет': [119, 2885, 1773, 1687417201],
#  'Представляем расширенный набор': [417, 1532, 474, 1691072406],
#  'Пробовали легендарную расшифро': [773, 2870, 1440, 1689338404],
#  'Самый масштабный в истории VK ': [555, 1581, 124, 1689775767],
#  'Уже разобрались в NFT и постав': [291, 739, 206, 1687423600]}

# %%
import schedule
import time

# %%
def task():
    print('Приветики, я опять запустился! Когда меня покормят? Хочу спать. Пока!')
    return
schedule.every(5).seconds.do(task) 
while True: 
    schedule.run_pending() 
    time.sleep(1)
# Out:
# Приветики, я опять запустился! Когда меня покормят? Хочу спать. Пока!
# Приветики, я опять запустился! Когда меня покормят? Хочу спать. Пока!
# Приветики, я опять запустился! Когда меня покормят? Хочу спать. Пока!
# Приветики, я опять запустился! Когда меня покормят? Хочу спать. Пока!
# Приветики, я опять запустился! Когда меня покормят? Хочу спать. Пока!
# Приветики, я опять запустился! Когда меня покормят? Хочу спать. Пока!
# Приветики, я опять запустился! Когда меня покормят? Хочу спать. Пока!
# Приветики, я опять запустился! Когда меня покормят? Хочу спать. Пока!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 8
#       6 while True:
#       7     schedule.run_pending()
# ----> 8     time.sleep(1)
#
# KeyboardInterrupt:
