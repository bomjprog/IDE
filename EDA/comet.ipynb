# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from comet_ml import Experiment

experiment = Experiment(
  api_key="m96vrE11xqa2r33IfjDFQxgAj",
  project_name="skillfactiry-ds",
  workspace="bomjprog"
)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET WARNING: You are trying to log string value as a metric. This is not recommended.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/bomjprog/skillfactiry-ds/db1cdacd189644b8881e4a83e37330e7

# %%
data = pd.read_csv('data/KaggleV2-May-2016.csv')

# %%
data.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
numeric_data = ['Age', 'Scholarship', 'Hipertension', 'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received']
sns.heatmap(data[numeric_data].corr(), annot=True, linewidths=.5)
experiment.log_figure(figure = plt)
# Out:
# {'web': 'https://www.comet.com/api/image/download?imageId=688a35e4c7d74cb086d5f1665dcce73d&experimentKey=db1cdacd189644b8881e4a83e37330e7',
#  'api': 'https://www.comet.com/api/rest/v1/image/get-image?imageId=688a35e4c7d74cb086d5f1665dcce73d&experimentKey=db1cdacd189644b8881e4a83e37330e7',
#  'imageId': '688a35e4c7d74cb086d5f1665dcce73d'}
